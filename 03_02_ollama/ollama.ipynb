# %%
# llamas (ollama 종료 안됨)
# !ollama stop llama
# Out:
# Error: couldn't find model "llama" to stop

# %%
# %pip install ollama
# Out:
# Collecting ollama
#   Downloading ollama-0.6.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: httpx>=0.27 in c:\users\playdata\llm\llm_venv\lib\site-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic>=2.9 in c:\users\playdata\llm\llm_venv\lib\site-packages (from ollama) (2.12.5)
# Requirement already satisfied: anyio in c:\users\playdata\llm\llm_venv\lib\site-packages (from httpx>=0.27->ollama) (4.12.1)
# Requirement already satisfied: certifi in c:\users\playdata\llm\llm_venv\lib\site-packages (from httpx>=0.27->ollama) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\playdata\llm\llm_venv\lib\site-packages (from httpx>=0.27->ollama) (1.0.9)
# Requirement already satisfied: idna in c:\users\playdata\llm\llm_venv\lib\site-packages (from httpx>=0.27->ollama) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\playdata\llm\llm_venv\lib\site-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\playdata\llm\llm_venv\lib\site-packages (from pydantic>=2.9->ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\playdata\llm\llm_venv\lib\site-packages (from pydantic>=2.9->ollama) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\playdata\llm\llm_venv\lib\site-packages (from pydantic>=2.9->ollama) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\playdata\llm\llm_venv\lib\site-packages (from pydantic>=2.9->ollama) (0.4.2)
# Downloading ollama-0.6.1-py3-none-any.whl (14 kB)
# Installing collected packages: ollama
# Successfully installed ollama-0.6.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import ollama

response = ollama.chat(model='llama3', messages=[{'role' : 'user', 'content' : '안녕 만나서 반가워!'}])

response
# Out:
# ChatResponse(model='llama3', created_at='2026-02-03T02:12:15.1628329Z', done=True, done_reason='stop', total_duration=4796595800, load_duration=77869900, prompt_eval_count=18, prompt_eval_duration=826605500, eval_count=29, eval_duration=3833151100, message=Message(role='assistant', content='😊 안녕하세요! 저도 반가워요! 좋은 날씨에 맞이해 좋은 추억을 만들어요! 😊', thinking=None, images=None, tool_name=None, tool_calls=None), logprobs=None)

# %%
import ollama

response = ollama.chat(model='llama3', messages=[{'role' : 'user', 'content' : '파이썬으로 퀵소트 구현해 줘'}])

response
# Out:
# ChatResponse(model='llama3', created_at='2026-02-03T02:15:05.8842041Z', done=True, done_reason='stop', total_duration=61744760300, load_duration=84618400, prompt_eval_count=25, prompt_eval_duration=982827600, eval_count=429, eval_duration=59606242700, message=Message(role='assistant', content='Here is a Python implementation of the quicksort algorithm:\n```python\ndef quicksort(arr):\n    if len(arr) <= 1:\n        return arr\n    pivot = arr[0]\n    less = [x for x in arr[1:] if x <= pivot]\n    greater = [x for x in arr[1:] if x > pivot]\n    return quicksort(less) + [pivot] + quicksort(greater)\n```\nHere\'s a breakdown of the algorithm:\n\n1. Base case: If the length of the input array is 0 or 1, return the original array (since it\'s already sorted).\n2. Choose a pivot element: In this implementation, we choose the first element of the array as the pivot.\n3. Partition the array: Divide the rest of the array into two parts:\n\t* `less`: elements that are less than or equal to the pivot\n\t* `greater`: elements that are greater than the pivot\n4. Recursively sort the subarrays: Call the `quicksort` function on each of these subarrays, and concatenate the results.\n5. Return the sorted array: The final result is the concatenation of the sorted `less` array, the pivot element, and the sorted `greater` array.\n\nHere\'s an example usage:\n```python\narr = [3, 6, 1, 8, 2, 4]\nprint(quicksort(arr))  # Output: [1, 2, 3, 4, 6, 8]\n```\nNote that this is a "Lomuto" partition scheme, which is a variation of the standard "Hoare" partition scheme. The Lomuto scheme is slightly faster and more efficient in practice.\n\nAlso, it\'s worth noting that quicksort has an average time complexity of O(n log n), but it can have worst-case performance of O(n^2) if the pivot is chosen poorly (e.g., always choosing the smallest or largest element). In practice, however, quicksort is often a reliable and efficient sorting algorithm.', thinking=None, images=None, tool_name=None, tool_calls=None), logprobs=None)
