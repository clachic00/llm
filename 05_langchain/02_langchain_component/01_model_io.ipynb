# %% [markdown]
# # Model I/O
#
# ![](https://d.pr/i/Wy5B5B+)

# %%
# %pip install langchain langchain-community langchain-openai langchain-huggingface python-dotenv -qqq
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# -q : 진행 로그 일부 숨김
# -qq : 대부분 숨김
# -qqq : 성공 메시지까지 거의다 숨김(문제가 생길경우만 로그 본다)

# %%
from dotenv import load_dotenv  # .env 파일의 환경변수 로드
import os                       # 환경변수 접근용

load_dotenv()                   # 현재 위치의 .env를 읽어와 환경변수로 등록
os.environ["OPENAI_API_KEY"] = os.getenv("openai_key")  # .env의 openai_key 값을 OPENAI_API_KEY로 등록
os.environ["LANGSMITH_TRACING"] = 'true'                # LangSmith 트레이싱 활성화
os.environ["LANGSMITH_ENDPOINT"] = 'https://api.smith.langchain.com'  # LangSmith API 엔드포인트 설정
os.environ["LANGSMITH_PROJECT"] = 'skn23-langchain'                   # LangSmith 프로젝트명 설정
os.environ["LANGSMITH_API_KEY"] = os.getenv("langsmith_key")          # .env의 langsmith_key 값을 LANGSMITH_API_KEY로 등록

# %% [markdown]
# ## Model
#
# ### OpenAI

# %%
from langchain_openai import ChatOpenAI  # OpenAI 채팅 모델을 Langchain에서 쓰는 래퍼 클래스

llm = ChatOpenAI(model='gpt-4.1-mini')         # llm 객체 생성
llm.invoke('프랑스의 여행지 추천해줘.').content  # 사용자 입력로 모델 호출 -> AIMessage(content) 반환
# Out:
# '프랑스는 다양한 매력적인 여행지가 많아요! 취향에 맞게 몇 가지 추천드릴게요.\n\n1. **파리(Paris)**  \n   - 에펠탑, 루브르 박물관, 노트르담 대성당, 몽마르트 언덕 등 세계적으로 유명한 명소가 많아요.  \n   - 예술과 문화, 쇼핑, 맛집을 즐기기 좋아요.\n\n2. **니스(Nice)**  \n   - 프랑스 남부 코트다쥐르 해변 도시로 따뜻한 지중해 기후와 아름다운 해변이 매력적입니다.  \n   - 프로방스 지역의 감성도 느낄 수 있어요.\n\n3. **보르도(Bordeaux)**  \n   - 와인으로 유명한 도시로, 와인 투어와 함께 아름다운 건축물을 감상할 수 있어요.  \n   - 프랑스 남서부의 미식 여행지로 추천합니다.\n\n4. **루아르 계곡(Loire Valley)**  \n   - 중세의 성(샤토)이 많은 롱드 계곡은 드라이브하며 중세 건축과 자연 경관을 즐기기 좋은 곳입니다.  \n   - 자전거 여행도 인기있어요.\n\n5. **스트라스부르(Strasbourg)**  \n   - 독일과 프랑스 문화가 어우러진 알자스 지방의 도시로, 목조 건축과 운하가 아름답습니다.  \n   - 크리스마스 마켓 시즌에 특히 매력적입니다.\n\n6. **몽생미셸(Mont Saint-Michel)**  \n   - 바다 한가운데 떠 있는 듯한 수도원으로 프랑스에서도 손꼽히는 관광 명소입니다.  \n   - 사진 찍기 좋은 장소예요.\n\n더 궁금한 점이나 특정 테마(예: 자연, 문화, 미식)에 맞는 여행지 추천도 가능하니 알려주세요!'

# %%
# init_chat_model : 추상화된 lm모델 객체 생성
from langchain.chat_models import init_chat_model

# OpenAI 모델 지정 + 파라미터 설정
# llm = init_chat_model(model='gpt-4.1-mini', model_provider='openai', temperature=1, top_p=1)
llm = init_chat_model(model='openai:gpt-4.1-mini', temperature=1, top_p=1)
ai_message = llm.invoke('핀란드의 여행지 추천해줘.')  # 프롬프트 호출 -> AIMessage 반환
ai_message.content  # 본문 텍스트만 출력
# Out:
# '핀란드는 자연과 도시가 조화롭게 어우러진 멋진 여행지입니다. 아래 몇 가지 추천 여행지를 소개할게요!\n\n1. **헬싱키 (Helsinki)**  \n   핀란드의 수도로 현대적이면서도 전통적인 분위기를 느낄 수 있어요.  \n   - 헬싱키 대성당, 우스펜스키 대성당 방문  \n   - 에스플라나디 공원 산책  \n   - 카페와 레스토랑에서 핀란드 음식 즐기기  \n   - 수오멘린나(Suomenlinna) 요새 탐방  \n\n2. **로바니에미 (Rovaniemi)**  \n   북극권에 위치한 도시로 산타클로스 마을이 유명해요.  \n   - 산타클로스 빌리지 방문  \n   - 오로라 관측 (가을부터 초봄까지 가능)  \n   - 순록 사파리, 개썰매 체험  \n   - 아르티쿰 박물관에서 북극권 문화 배우기  \n\n3. **사리셀카 (Saariselkä)**  \n   라플란드 지역에서 자연 체험을 원한다면 좋아요.  \n   - 핀란드 국립공원(Kiilopää) 하이킹  \n   - 겨울철 스키와 눈썰매 타기  \n   - 오로라 투어 예약  \n\n4. **탐페레 (Tampere)**  \n   핀란드 내륙의 문화와 역사를 체험할 수 있는 도시입니다.  \n   - 발라토리 광장과 탐페레 대성당  \n   - 무민 박물관(Moomin Museum) 방문  \n   - 라핀마키 야외 박물관 탐방  \n\n5. **쿠오피오 (Kuopio)**  \n   호수가 많은 지역으로 산과 호수 풍경이 아름답습니다.  \n   - 칼라바타(Kallavesi) 호수에서 보트 타기  \n   - 소피아교회 전망대에서 경치 감상  \n   - 핀란드 사우나 체험  \n\n핀란드는 사계절 모두 매력이 있지만 특히 겨울철에는 오로라와 겨울 스포츠, 여름철에는 백야 현상과 자연 트레킹을 즐길 수 있어서 다양한 스타일의 여행이 가능해요. 여행 일정과 관심사에 맞게 선택해 보세요!'

# %% [markdown]
# - 추상화된 채팅 LLM : init_chat_model()이 특정회사(OpenAI / Anthropic / HuggingFace)의 클래스에 직접 묶이지 않게,
# 공통 인터페이스로 같은 방식(invoke, stream 등)으로 쓰게 만들어준다.
# 즉, init_chat_model()은 OpenAI 객체를 만드는 방식이 아니라, 여러 채팅 LLM들을 공통 규격으로 감싸서(추상화해서)
# 동일하게 쓸수 있도록 만들어주는 팩토리 함수

# %% [markdown]
# ### HuggingFace

# %%
# init_chat_model : 추상화된 lm모델 객체 생성
from langchain.chat_models import init_chat_model

# OpenAI 모델 지정 + 파라미터 설정
llm = init_chat_model(model='huggingface:Qwen/Qwen2.5-0.5B-Instruct', temperature=1)
ai_message = llm.invoke('Translate this to French. I love programming~')  # 프롬프트 호출 -> AIMessage 반환
ai_message.content  # 본문 텍스트만 출력
# Out:
# c:\Users\Playdata\nlp\nlp_venv\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Playdata\.cache\huggingface\hub\models--Qwen--Qwen2.5-0.5B-Instruct. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Device set to use cpu
# '<|im_start|>system\nYou are Qwen, created by Alibaba Cloud. You are a helpful assistant.<|im_end|>\n<|im_start|>user\nTranslate this to French. I love programming~<|im_end|>\n<|im_start|>assistant\nJe aime le programmation~'

# %% [markdown]
# ### 모델 후보군 비교

# %%
# 서로 다른 provider 모델들을 리스트로 준비
models = [
    init_chat_model('openai:gpt-4.1-mini'),
    init_chat_model('huggingface:Qwen/Qwen2.5-0.5B-Instruct'),
]

user_prompt = '랭체인의 장점이 뭐야?'  # 사용자 질문

for model in models:
    # model 객체에 model_name 속성이 있으면 model_name, 없으면 model_id를 사용
    model_name = model.model_name if hasattr(model, 'model_name') else model.model_id
    print(f"===== {model_name} =====")
    ai_message = model.invoke(user_prompt)  # 모델 호출
    print(ai_message.content)
    print()
# Out:
# Device set to use cpu
# ===== gpt-4.1-mini =====
# 랭체인(LangChain)의 주요 장점은 다음과 같습니다:
#
# 1. **언어 모델 통합의 용이성**
#    랭체인은 다양한 언어 모델(예: OpenAI GPT, Cohere, Hugging Face 등)을 쉽고 일관된 인터페이스로 통합할 수 있도록 도와줍니다. 덕분에 여러 모델을 비교하거나 혼합하여 사용할 때 개발 효율이 크게 향상됩니다.
#
# 2. **체인(chain) 구성 지원**
#    랭체인은 여러 개의 작업(예: 질문 응답, 텍스트 요약, 데이터 추출 등)을 연속적으로 연결하는 체인을 만들 수 있게 해 줍니다. 이런 체인 방식은 복잡한 작업을 단계별로 분리하여 관리하기 좋아 유지보수와 확장성이 뛰어납니다.
#
# 3. **다양한 도구 및 인터페이스 제공**
#    문서 검색, 메타데이터 처리, 데이터베이스 연동 등 다양한 도구들을 기본으로 지원하여 LLM 애플리케이션을 쉽게 만들 수 있도록 돕습니다.
#
# 4. **유연한 커스터마이징**
#    사용자가 직접 체인, 프롬프트, 콜백, 파이프라인 등을 자유롭게 설계하고 조합할 수 있어서 특정 요구사항에 맞춘 맞춤형 애플리케이션 개발이 가능합니다.
#
# 5. **오픈소스 및 활발한 커뮤니티**
#    랭체인은 오픈소스 프로젝트이며, 활발한 개발자 커뮤니티가 있어 지속적인 업데이트와 다양한 활용 사례, 튜토리얼을 쉽게 접할 수 있습니다.
#
# 6. **확장성**
#    기본적인 챗봇에서부터 복잡한 지식기반 시스템, 데이터 파이프라인까지 다양한 규모와 분야에 맞춰 확장할 수 있습니다.
#
# 요약하면, 랭체인은 대규모 언어 모델을 활용한 애플리케이션을 빠르고 효율적으로 설계, 개발, 관리할 수 있도록 돕는 강력한 라이브러리입니다.
#
# ===== Qwen/Qwen2.5-0.5B-Instruct =====
# <|im_start|>system
# You are Qwen, created by Alibaba Cloud. You are a helpful assistant.<|im_end|>
# <|im_start|>user
# 랭체인의 장점이 뭐야?<|im_end|>
# <|im_start|>assistant
# 랭크 인의 장점은 다양합니다:
#
# 1. 랭킹 기반의 경쟁: 게임에서의 가장 중요한 부분 중 하나는 랭킹입니다. 이로써 플레이어들은 자신들의 성적을 보여주는 역할을 합니다.
#
# 2. 플레이어의 성장 및 개발: 랭킹은 플레이어가 능력을 향상시키고 개선하는 데 도움이 됩니다.
#
# 3. 플레이어와 게임의 관계: 게임 내에서는 플레이어와 게임의 관계를 강조하고 있습니다. 게임의 승패에 대한 상황은 플레이어가 결정할 수 있는 요소입니다.
#
# 4. 플레이어의 신뢰성: 랭킹은 플레이어들에게 신뢰감을 부여하며, 이를 통해 그들이 게임을 더 잘 지키기 위해 노력하게 만듭니다.
#
# 5. 게임의 의미: 랭킹은 게임의 의미와 가치를 표현하고, 그들 자신의 성적을 인정하기 위한 방법으로 활용됩니다.
#
# 6. 게임의 평화적 과정

# %% [markdown]
# ## Prompt

# %%
# 시스템/유저 메시지 리스트로 ChatModel을 호출해 응답을 출력
llm = init_chat_model('openai:gpt-4.1-mini')  # OpenAI 채팅 모델 초기화

# (role, content) 튜플 형태의 대화 메시지
messages = [
    ('system', '당신은 친절한 챗봇입니다.'),           # 시스템 프롬프트
    ('user', '랭체인/랭그래프를 간단히 설명해주세요.')  # 유저 메시지
]

ai_message = llm.invoke(messages)
ai_message.content
# Out:
# '랭체인(LangChain)과 랭그래프(LangGraph)는 인공지능, 특히 자연어 처리와 관련된 도구 및 개념입니다. 간단히 설명드리면:\n\n- **랭체인 (LangChain)**: 여러 AI 언어 모델과 다양한 데이터 소스, 도구들을 연결하여 복잡한 애플리케이션을 쉽게 만들 수 있게 해주는 오픈소스 프레임워크입니다. 예를 들어, 자연어 질문에 대해 여러 단계를 거쳐 답변을 생성하거나, 외부 데이터베이스와 연동하여 정보를 실시간으로 가져오는 등의 작업을 할 때 활용됩니다.\n\n- **랭그래프 (LangGraph)**: 랭체인에서 파생된 또는 관련된 개념으로, 여러 AI 모델들, 데이터 소스, 프로세스들을 그래프 구조로 시각화하고 관리하는 방법론 또는 도구입니다. 복잡한 작업의 흐름(워크플로우)을 이해하고 최적화하는 데 도움을 줍니다.\n\n요약하면, 랭체인은 AI 언어 모델을 연결해 애플리케이션을 만들기 위한 프레임워크이고, 랭그래프는 이런 연결과 작업 흐름을 시각적·구조적으로 관리하는 방법이라고 할 수 있습니다.'

# %%
# Langchain 메시지 객체(System/Human)로 LLM을 호출해 응답을 출력
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage, ToolMessage
llm = init_chat_model('openai:gpt-4.1-mini')  # OpenAI 채팅 모델 초기화

# (role, content) 튜플 형태의 대화 메시지
messages = [
    SystemMessage('당신은 친절한 챗봇입니다.'),           # 시스템 프롬프트
    HumanMessage('랭체인/랭그래프를 간단히 설명해주세요.')  # 유저 메시지
]

ai_message = llm.invoke(messages)
ai_message.content
# Out:
# '랭체인(LangChain)과 랭그래프(LangGraph)는 인공지능 언어모델(예: GPT)을 효과적으로 활용하고, 복잡한 작업을 구성할 수 있게 돕는 도구입니다.\n\n- **랭체인 (LangChain)**  \n  랭체인은 여러 언어 모델과 외부 데이터 소스, 함수 호출 등을 연결하여 복합적인 작업 흐름(chain)을 만드는 프레임워크입니다. 예를 들어, 사용자의 질문을 이해하고, 관련 정보를 검색한 뒤, 답변을 생성하는 과정을 순차적으로 구성할 수 있습니다.\n\n- **랭그래프 (LangGraph)**  \n  랭그래프는 랭체인과 유사한 개념으로, 작업을 노드와 간선으로 표현한 그래프 형태로 구성해 복잡한 프로세스를 시각화하고 관리할 수 있게 해줍니다. 이를 통해 다양한 작업 단계를 유기적으로 연동할 수 있습니다.\n\n간단히 말해, 랭체인과 랭그래프는 언어 모델을 중심으로 여러 기능과 데이터를 유기적으로 연결해 복잡한 인공지능 작업을 쉽게 설계하고 실행하도록 도와주는 도구들입니다.'

# %%
# PromptTemplate으로 프롬프트를 템플릿화해서 상품별 문구를 만들고 LLM을 생성
from langchain_core.prompts import PromptTemplate

# 변수 {product}를 포함한 템플릿 생성
prompt = PromptTemplate.from_template('{product}를 홍보하기 위한 참신한 문구를 작성해 줘.')
print(prompt)  # 객체 정보
print(prompt.format(product='전기차'))  # 변수를 채운 완성된 프롬프트 문자열
print(prompt.format(product='카메라'))  # 변수를 채운 완성된 프롬프트 문자열

llm = init_chat_model('openai:gpt-4.1-mini')

ai_message = llm.invoke(prompt.format(product='전기차'))
ai_message.content
# Out:
# input_variables=['product'] input_types={} partial_variables={} template='{product}를 홍보하기 위한 참신한 문구를 작성해 줘.'
# 전기차를 홍보하기 위한 참신한 문구를 작성해 줘.
# 카메라를 홍보하기 위한 참신한 문구를 작성해 줘.
# '물론입니다! 전기차를 홍보하기 위한 참신한 문구를 몇 가지 제안해 드릴게요.\n\n1. **"미래를 달리는 힘, 전기차와 함께 오늘을 바꾸다."**  \n2. **"탄소 없는 여행, 전기차가 만들어가는 깨끗한 내일."**  \n3. **"조용히, 빠르게, 친환경으로 – 전기차가 당신의 새로운 드라이브입니다."**  \n4. **"충전 한 번으로 지구를 지키는 힘을 경험하세요."**  \n5. **"소음은 줄이고, 자유는 더하고 – 전기차가 선사하는 혁신적인 드라이브."**  \n6. **"지속 가능한 여정, 전기차와 함께 시작하세요."**\n\n필요에 따라 더 캐주얼하거나 고급스러운 톤으로도 조정 가능합니다. 원하시면 말씀해 주세요!'

# %%
# ChatPromptTemplate으로 멀티턴(시스템/유저) 프롬프트를 템플릿화 하여 LLM 호출
from langchain_core.prompts import ChatPromptTemplate

# 여러 메시지(role, content)를 템플릿으로 구성
chat_prompt = ChatPromptTemplate.from_messages([
    ('system', '당신은 {domain}분야의 전문가입니다. 친절히 답해주세요.'),
    ('user', '{question} 한글로 답해주세요.'),
])

print(chat_prompt)
print(chat_prompt.format(domain='IT', question='langsmith 사용법'))  # 변수를 채운 결과

llm = init_chat_model('openai:gpt-4.1-mini')

ai_message = llm.invoke(chat_prompt.format(domain='IT', question='langsmith 사용법'))
ai_message.content
# Out:
# input_variables=['domain', 'question'] input_types={} partial_variables={} messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['domain'], input_types={}, partial_variables={}, template='당신은 {domain}분야의 전문가입니다. 친절히 답해주세요.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['question'], input_types={}, partial_variables={}, template='{question} 한글로 답해주세요.'), additional_kwargs={})]
# System: 당신은 IT분야의 전문가입니다. 친절히 답해주세요.
# Human: langsmith 사용법 한글로 답해주세요.
# '안녕하세요! LangSmith 사용법에 대해 한글로 친절히 설명드리겠습니다.\n\n### LangSmith란?\nLangSmith는 언어 모델(Large Language Model, LLM)과 관련된 작업을 쉽게 관리하고 분석할 수 있도록 도와주는 개발 도구입니다. 주로 대화형 AI 개발, 프롬프트(입력문) 관리, 실행 로그 추적 등 다양한 기능을 제공합니다.\n\n---\n\n### LangSmith 사용법 기본 가이드\n\n#### 1. LangSmith 설치\n먼저 LangSmith를 사용하려면 Python 환경에 패키지를 설치해야 합니다.\n\n```bash\npip install langsmith\n```\n\n#### 2. API 키 설정\nLangSmith는 API 키를 통해 서비스를 사용합니다. API 키는 LangSmith 서비스를 제공하는 플랫폼에서 발급받으시면 됩니다.\n환경변수로 설정하는 방법이 일반적입니다.\n\n```bash\nexport LANGSMITH_API_KEY="발급받은_API_키"\n```\n\n윈도우에서는 PowerShell에서:\n\n```powershell\nsetx LANGSMITH_API_KEY "발급받은_API_키"\n```\n\n#### 3. LangSmith 기본 사용법\n다음은 Python에서 LangSmith를 간단히 사용하는 예입니다.\n\n```python\nfrom langsmith import Client\n\n# API 키를 이용해 클라이언트 생성\nclient = Client()\n\n# 예: 간단한 프롬프트를 실행해 보고 결과 받기\nresponse = client.execute_prompt("Hello, LangSmith! 어떻게 도와드릴까요?")\nprint(response)\n```\n\n#### 4. 프롬프트 관리하기\nLangSmith는 프롬프트를 저장하고 버전 관리를 지원합니다.\n\n```python\nprompt = client.create_prompt(name="인사 프롬프트", text="안녕하세요! 무엇을 도와드릴까요?")\nprint(f"프롬프트 ID: {prompt.id}")\n```\n\n#### 5. 실행 로그(Invocation) 추적\n사용자가 입력한 프롬프트와 모델 응답 기록을 남겨, 나중에 분석하거나 디버깅할 수 있습니다.\n\n```python\ninvocation = client.invoke_prompt(prompt_id=prompt.id, input_data={"user_message": "안녕"})\nprint(invocation.response)\n```\n\n---\n\n### 참고할 점\n- LangSmith는 보통 LangChain과 함께 사용하면 더욱 강력합니다.\n- 다양한 언어 모델과 연동 가능하며, 여러분의 프로젝트에 맞게 커스텀 가능합니다.\n- 자세한 기능과 활용법은 공식 문서(영문)나 GitHub 레포지토리를 참고하세요.\n\n---\n\n필요하신 부분이나 예제 코드를 더 원하시면 말씀해 주세요!'

# %% [markdown]
# ## Output Parser
# 객체의 출력에서 실제 값부분을 가져와 후처리 작업 담당

# %%
# CommaSeparatedListOutputParser : 콤마 구분 문자열 -> 리스트 변환 파서
from langchain_core.output_parsers import CommaSeparatedListOutputParser

parser = CommaSeparatedListOutputParser()  # 객체 생성
model_output = '달걀, 고구마, 대파, 쪽파'    # 모델의 출력
parser.parse(model_output)
# Out:
# ['달걀', '고구마', '대파', '쪽파']

# %%
format_instruction = parser.get_format_instructions()  # 파서가 원하는 출력 형태 지시문 생성
print(format_instruction)

prompt = PromptTemplate(
    # subject/n + 지시사항을 포함한 템플릿
    template='{subject} 팀 {n}개를 작성해주세요. \n(지시사항: {format_instruction})',
    input_variables= ['subject', 'n'],  # 사용자가 채울 변수들
    partial_variables={'format_instruction': format_instruction}  # 고정으로 주입할 변수
)

print(prompt)  # 템플릿 구조
print(prompt.format(subject='프로야구', n=5))  # 변수를 채운 최종 프롬프트 문자열
# Out:
# Your response should be a list of comma separated values, eg: `foo, bar, baz` or `foo,bar,baz`
# input_variables=['n', 'subject'] input_types={} partial_variables={'format_instruction': 'Your response should be a list of comma separated values, eg: `foo, bar, baz` or `foo,bar,baz`'} template='{subject} 팀 {n}개를 작성해주세요. \n(지시사항: {format_instruction})'
# 프로야구 팀 5개를 작성해주세요.
# (지시사항: Your response should be a list of comma separated values, eg: `foo, bar, baz` or `foo,bar,baz`)

# %%
# 프롬프트 템플릿 -> LLM 호출 -> OutputParser로 리스트 변환
input = prompt.invoke({'subject': '프로야구', 'n': 5})  # 변수 (subject, n)을 넣어 프롬프트 메시지 생성
print(input)

llm = init_chat_model('openai:gpt-4.1-mini')
ai_message = llm.invoke(input)
print(ai_message.content)

parser = CommaSeparatedListOutputParser()
output = parser.invoke(ai_message)         # LLM 응답을 콤마 기준으로 파싱 -> 파이썬 리스트
print(output)
# Out:
# text='프로야구 팀 5개를 작성해주세요. \n(지시사항: Your response should be a list of comma separated values, eg: `foo, bar, baz` or `foo,bar,baz`)'
# 두산 베어스, 삼성 라이온즈, LG 트윈스, 키움 히어로즈, 한화 이글스
# ['두산 베어스', '삼성 라이온즈', 'LG 트윈스', '키움 히어로즈', '한화 이글스']

# %%
# LCEL(파이프)로 Prompt -> LLM -> OutputParser를 하나의 체인으로 연결해 실행
chain = prompt | llm | parser  # 체인 : 프롬프트 -> 모델 -> 파서
chain.invoke({'subject': '프로야구', 'n': 5})
# Out:
# ['두산 베어스', '삼성 라이온즈', '키움 히어로즈', 'LG 트윈스', '한화 이글스']

# %%
# StrOutputParser : 모델 응답을 가공없이 문자열로 받아 출력
from langchain_core.output_parsers import StrOutputParser  # AIMessage -> str(content) 변환해주는 파서
parser = StrOutputParser()  # 파서 객체 생성
chain = llm | parser        # LLM 출력 -> 문자열로 파싱
chain.invoke('겨울 제철 과일은 뭐가 있어?')
# Out:
# '겨울 제철 과일로는 다음과 같은 것들이 있어요:\n\n1. **감** - 달콤하고 부드러운 맛이 특징으로 겨울철 대표 과일입니다.\n2. **귤** - 새콤달콤하고 비타민 C가 풍부해 겨울철 감기 예방에 좋아요.\n3. **사과** - 아삭하고 상큼한 맛으로 겨울에도 많이 즐겨 먹는 과일이에요.\n4. **배** - 부드럽고 시원한 과즙이 가득해 겨울철에 특히 인기입니다.\n5. **유자** - 즙을 내어 차로 많이 활용하며 겨울철 비타민 C 보충에 좋아요.\n6. **홍시** - 완전히 익은 감으로 아주 부드럽고 달콤한 맛을 즐길 수 있어요.\n\n겨울에는 이 과일들을 신선하게 맛볼 수 있으니 건강 간식으로 활용해 보세요!'

# %%
# JsonOutputParser : 모델의 json 문자열 응답을 파이썬 객체 dict/list로 변환(파싱)하는 파서
from langchain_core.output_parsers import JsonOutputParser

parser = JsonOutputParser()
format_instruction = parser.get_format_instructions()  # 모델에게 JSON으로 답하라고 지시하는 문구 생성
print(format_instruction)

prompt = PromptTemplate(
    # subject/n + JSON 지시사항 포함
    template = '{subject}분야의 유명한 한국어 책 {n}권 정보를 제공해주세요.\n(지시사항: {format_instruction})',
    input_variables = ['subject', 'n'],  # 사용자가 채울 변수들
    partial_variables ={'format_instruction': format_instruction}  # 고정으로 주입할 변수
)

chain = prompt | llm | parser  # 체인 : 프롬프트 -> LLM -> JSON 파서
result = chain.invoke({'subject': '인공지능', 'n': 5})
result
# Out:
# Return a JSON object.
# {'books': [{'title': '파이썬으로 배우는 인공지능',
#    'author': '김성훈',
#    'publisher': '한빛미디어',
#    'year': 2018,
#    'description': '초보자를 위한 파이썬 기반 인공지능 입문서로, 기초부터 실습까지 폭넓게 다룬다.'},
#   {'title': 'Deep Learning with Python',
#    'author': '프랑소와 숄레 (저), 김용범 (역)',
#    'publisher': '한빛미디어',
#    'year': 2018,
#    'description': '케라스 창시자가 쓴 딥러닝 입문서로, 한국어 번역본.'},
#   {'title': '인공지능 기초부터 활용까지',
#    'author': '이광호',
#    'publisher': '생능출판',
#    'year': 2020,
#    'description': '인공지능의 기본 개념부터 최신 기술까지 폭넓게 소개하는 책.'},
#   {'title': '파이썬과 케라스로 배우는 딥러닝',
#    'author': '박해선',
#    'publisher': '길벗',
#    'year': 2020,
#    'description': '파이썬과 케라스를 활용한 딥러닝 실습 중심의 국내 도서.'},
#   {'title': '머신러닝 교과서 with 파이썬, 사이킷런, 텐서플로',
#    'author': '세바스찬 라시카, 바히드 미잘리 (공동저자), 김태헌 (역)',
#    'publisher': '한빛미디어',
#    'year': 2020,
#    'description': '머신러닝의 기초 개념부터 실전까지 체계적으로 다루는 실무서.'}]}

# %%
# PydanticOutputParser : 스키마(형식)를 강제해서 구조화된 책 목록을 받는 코드
from pydantic import BaseModel  # 데이터 스키마(모델) 정의용
from langchain_core.output_parsers import PydanticOutputParser  # LLM 출력 -> Pydantic 객체로 검증/변환
from typing import List  # 리스트 타입 힌트용

# 책 1권마다의 스키마 정의
class Book(BaseModel):
    title: str
    author: str
    publisher: str
    year: int = None  # 출간연도(없어도 상관없음)
    description: str

# 책 여러권을 담는 스키마 정의
class BookList(BaseModel):
    books: List[Book]

parser = PydanticOutputParser(pydantic_object=BookList)  # 출력이 BookList 형태가 되도록 파서 생성
format_instruction = parser.get_format_instructions()    # 스키마대로 출력하도록 만드는 지시문
print(format_instruction)

prompt = PromptTemplate(
    # subject/n + JSON 지시사항 포함
    template = '{subject}분야의 유명한 한국어 책 {n}권 정보를 제공해주세요.\n(지시사항: {format_instruction})',
    input_variables = ['subject', 'n'],  # 사용자가 채울 변수들
    partial_variables ={'format_instruction': format_instruction}  # 고정으로 주입할 변수
)

chain = prompt | llm | parser  # 체인 : 프롬프트 -> LLM -> Pydantic 파서
result = chain.invoke({'subject': '인공지능', 'n': 5})  # 파싱/검증된 BookList 객체 반환
result
# Out:
# The output should be formatted as a JSON instance that conforms to the JSON schema below.
#
# As an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}
# the object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.
#
# Here is the output schema:
# ```
# {"$defs": {"Book": {"properties": {"title": {"title": "Title", "type": "string"}, "author": {"title": "Author", "type": "string"}, "publisher": {"title": "Publisher", "type": "string"}, "year": {"default": null, "title": "Year", "type": "integer"}, "description": {"title": "Description", "type": "string"}}, "required": ["title", "author", "publisher", "description"], "title": "Book", "type": "object"}}, "properties": {"books": {"items": {"$ref": "#/$defs/Book"}, "title": "Books", "type": "array"}}, "required": ["books"]}
# ```
# BookList(books=[Book(title='딥러닝 입문', author='조규현', publisher='한빛미디어', year=2017, description='딥러닝의 기본 개념부터 실습까지 쉽게 설명한 입문서로, 인공지능 분야 초심자에게 적합한 책입니다.'), Book(title='파이썬 머신러닝 완벽 가이드', author='권철민', publisher='위키북스', year=2019, description='파이썬을 활용한 머신러닝 기초와 주요 알고리즘을 상세히 다루며, 실제 프로젝트에 적용할 수 있도록 안내합니다.'), Book(title='인공지능: 현대적인 접근', author='스튜어트 러셀, 피터 노빅 (저자), 임백준 (역자)', publisher='한빛아카데미', year=2020, description='인공지능 분야의 고전이자 표준 교재로, 최신 연구 동향과 핵심 이론을 한국어로 자세히 소개합니다.'), Book(title='텐서플로와 케라스로 배우는 실전 딥러닝', author='윤성우', publisher='한빛미디어', year=2020, description='텐서플로우와 케라스 라이브러리를 활용해 딥러닝 모델을 구현하며, 실전 프로젝트 중심으로 설명합니다.'), Book(title='머신러닝 교과서 with 파이썬, 사이킷런, 텐서플로', author='세바스찬 라시카 (저자), 민경태 (역자)', publisher='에이콘출판', year=2019, description='파이썬을 이용한 머신러닝 이론과 실습을 폭넓게 다루며, 주요 알고리즘 원리 이해와 구현 방법을 체계적으로 설명합니다.')])

# %% [markdown]
# - Book / BookList는 pydantic.BaseModel을 상속한 스키마(데이터 모델)이다.
# - result는 그 스키마로 만들어진 Pydantic 객체(인스턴스)
#
# - 사용하면
#     - 필드가 있는지 검사
#     - 타입 검사/변환
#     - 구조가 맞는지 검사
#
# - dictionary와 차이점
#     - dict : 아무키나 들어갈수 있고, 타입도 상관없다.
#     - Pydatic 객체 : 정해진 키/타입만 허용. 틀리면 잡아줌(검증)

# %%
# with_structured_output() : Pydantic 스키마를 받아 구조화된 결과를 바로 받음
prompt = PromptTemplate(
    # subject/n + JSON 지시사항 포함
    template = '{subject}분야의 유명한 한국어 책 {n}권 정보를 제공해주세요.)',
    input_variables = ['subject', 'n']  # 사용자가 채울 변수들
)

chain = prompt | llm.with_structured_output(BookList)  # LLM의 출력이 BookList 스키마를 따르도록 래핑
result = chain.invoke({'subject': '인공지능', 'n': 5})  # 파싱/검증된 BookList 객체 반환
result
# Out:
# BookList(books=[Book(title='딥러닝 입문', author='조규태', publisher='한빛미디어', year=2019, description='딥러닝의 기본 개념과 실습을 다루는 입문서로, 인공지능 학습에 적합한 한국어 교재입니다.'), Book(title='파이썬으로 배우는 인공지능과 머신러닝', author='박해선', publisher='비제이퍼블릭', year=2020, description='파이썬을 활용한 인공지능과 머신러닝의 이론과 실습을 제공하는 책으로 초보자에게 적합합니다.'), Book(title='인공지능: 현대적 접근', author='스튜어트 러셀, 피터 노빅 (저자), 이광근 (역자)', publisher='한빛아카데미', year=2021, description='인공지능 분야의 대표적 교재로, 한국어 번역본이며 이론부터 응용까지 폭넓게 다룹니다.'), Book(title='머신러닝 교과서 with 파이썬, 사이킷런, 텐서플로', author='세바스찬 라쉬카, 바히둘라 하비브', publisher='한빛미디어', year=2018, description='파이썬 기반 머신러닝 입문서로, 다양한 알고리즘과 실습 예제를 제공합니다.'), Book(title='인공지능 시대의 윤리와 사회', author='최재붕 외', publisher='미래의창', year=2022, description='인공지능 기술이 사회와 윤리에 미치는 영향에 대해 분석한 책으로, 한국어로 되어있습니다.')])
